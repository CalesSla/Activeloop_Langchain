# %% [markdown]
# CharacterTextSplitter

# %%
from langchain.document_loaders import PyPDFLoader
loader = PyPDFLoader('testing.pdf')
pages = loader.load_and_split()

from langchain.text_splitter import CharacterTextSplitter

text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=20)
texts = text_splitter.split_documents(pages)

print(f"You have {len(texts)} documents")
print("Preview:")
print(texts[0].page_content)
# Out:
# You have 2 documents
# Preview:
# THE ONE     PAGE LINUX MANUALA summary of useful Linux commands
# Version 3.0 May 1999 squadron@powerup.com.au
# Starting & Stopping
# shutdown -h now Shutdown the system now and do not
# reboot
# halt Stop all processes - same as above
# shutdown -r 5 Shutdown the system in 5 minutes and
# reboot
# shutdown -r now Shutdown the system now and reboot
# reboot Stop all processes and then reboot - same
# as above
# startx Start the X system
# Accessing & mounting file systems
# mount -t iso9660 /dev/cdrom
# /mnt/cdromMount the device cdrom
# and call it cdrom under the
# /mnt directory
# mount -t msdos /dev/hdd
# /mnt/ddriveMount hard disk “d” as a
# msdos file system and call
# it ddrive under the /mnt
# directory
# mount -t vfat /dev/hda1
# /mnt/cdriveMount hard disk “a” as a
# VFAT file system and call it
# cdrive under the /mnt
# directory
# umount /mnt/cdrom Unmount the cdrom
# Finding files and text within files
# find / -name  fname Starting with the root directory, look
# for the file called fname
# find / -name ”*fname* ” Starting with the root directory, look
# for the file containing the string fname
# locate missingfilename Find a file called missingfilename
# using the locate command - this
# assumes you have already used the
# command updatedb (see next)
# updatedb Create or update the database of files
# on all file systems attached to the linux
# root directory
# which missingfilename Show the subdirectory containing the
# executable file  called missingfilename
# grep textstringtofind
# /dirStarting with the directory called dir ,
# look for and list all files containing
# textstringtofind
# The X Window System
# xvidtune Run the X graphics tuning utility
# XF86Setup Run the X configuration menu with
# automatic probing of graphics cards
# Xconfigurator Run another X configuration menu with
# automatic probing of graphics cards
# xf86config Run a text based X configuration menu
# Moving, copying, deleting & viewing files
# ls -l List files in current directory using
# long format
# ls -F List files in current directory and
# indicate the file type
# ls -laC List all files in current directory in
# long format and display in columnsrm name Remove a file or directory called
# name
# rm -rf name Kill off an entire directory and all it’s
# includes files and subdirectories
# cp filename
# /home/dirnameCopy the file called filename to the
# /home/dirname directory
# mv filename
# /home/dirnameMove the file called filename to the
# /home/dirname directory
# cat filetoview Display the file called filetoview
# man -k keyword Display man pages containing
# keyword
# more filetoview Display the file called filetoview one
# page at a time, proceed to next page
# using the spacebar
# head filetoview Display the first 10 lines of the file
# called filetoview
# head -20 filetoview Display the first 20 lines of the file
# called filetoview
# tail filetoview Display the last 10 lines of the file
# called filetoview
# tail -20 filetoview Display the last 20 lines of the file
# called filetoview
# Installing software for Linux
# rpm -ihv name.rpm Install the rpm package called name
# rpm -Uhv name.rpm Upgrade the rpm package called
# name
# rpm -e package Delete the rpm package called
# package
# rpm -l package List the files in the package called
# package
# rpm -ql package List the files and state the installed
# version of the package called
# package
# rpm -i --force package Reinstall the rpm package called
# name having deleted parts of it (not
# deleting using rpm -e)
# tar -zxvf archive.tar.gz or
# tar -zxvf archive.tgzDecompress the files contained in
# the zipped and tarred archive called
# archive
# ./configure Execute the script preparing the
# installed files for compiling
# User Administration
# adduser accountname Create a new user call accountname
# passwd accountname Give accountname a new password
# su Log in as superuser from current login
# exit Stop being superuser and revert to
# normal user
# Little known tips and tricks
# ifconfig List ip addresses for all devices on
# the machine
# apropos subject List manual pages for subject
# usermount Executes graphical application for
# mounting and unmounting file
# systems

# %% [markdown]
# RecursiveCharacterTextSplitter

# %%
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

loader = PyPDFLoader('testing.pdf')
pages = loader.load_and_split()

text_splitter = RecursiveCharacterTextSplitter(chunk_size=50,
                                               chunk_overlap=10,
                                               length_function=len)

docs = text_splitter.split_documents(pages)

for doc in docs:
    print(doc)
# Out:
# page_content='THE ONE     PAGE LINUX MANUALA summary of useful' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='of useful Linux commands' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='Version 3.0 May 1999 squadron@powerup.com.au' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='Starting & Stopping' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='shutdown -h now Shutdown the system now and do' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='and do not' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='reboot\nhalt Stop all processes - same as above' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='shutdown -r 5 Shutdown the system in 5 minutes' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='5 minutes and' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='reboot' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='shutdown -r now Shutdown the system now and' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='now and reboot' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='reboot Stop all processes and then reboot - same' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='as above\nstartx Start the X system' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='Accessing & mounting file systems' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='mount -t iso9660 /dev/cdrom' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='/mnt/cdromMount the device cdrom' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='and call it cdrom under the\n/mnt directory' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='mount -t msdos /dev/hdd' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='/mnt/ddriveMount hard disk “d” as a' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='msdos file system and call' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='it ddrive under the /mnt\ndirectory' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='directory\nmount -t vfat /dev/hda1' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='/mnt/cdriveMount hard disk “a” as a' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='VFAT file system and call it' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='cdrive under the /mnt\ndirectory' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='directory\numount /mnt/cdrom Unmount the cdrom' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='Finding files and text within files' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='find / -name  fname Starting with the root' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='the root directory, look' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='for the file called fname' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='find / -name ”*fname* ” Starting with the root' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='the root directory, look' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='for the file containing the string fname' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='locate missingfilename Find a file called' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='called missingfilename' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='using the locate command - this' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='assumes you have already used the' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='command updatedb (see next)' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='updatedb Create or update the database of files' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='on all file systems attached to the linux' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='root directory' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='which missingfilename Show the subdirectory' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='containing the' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='executable file  called missingfilename' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='grep textstringtofind' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='/dirStarting with the directory called dir ,' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='look for and list all files containing' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='textstringtofind\nThe X Window System' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='xvidtune Run the X graphics tuning utility' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='XF86Setup Run the X configuration menu with' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='automatic probing of graphics cards' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='Xconfigurator Run another X configuration menu' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='menu with' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='automatic probing of graphics cards' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='xf86config Run a text based X configuration menu' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='Moving, copying, deleting & viewing files' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='ls -l List files in current directory using' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='long format' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='ls -F List files in current directory and' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='indicate the file type' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='ls -laC List all files in current directory in' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='long format and display in columnsrm name Remove' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='Remove a file or directory called' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='name' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='rm -rf name Kill off an entire directory and all' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='and all it’s' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='includes files and subdirectories\ncp filename' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='/home/dirnameCopy the file called filename to the' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='/home/dirname directory\nmv filename' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='/home/dirnameMove the file called filename to the' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='/home/dirname directory' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='cat filetoview Display the file called filetoview' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='man -k keyword Display man pages containing' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='keyword' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='more filetoview Display the file called' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='called filetoview one' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='page at a time, proceed to next page' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='using the spacebar' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='head filetoview Display the first 10 lines of the' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='of the file' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='called filetoview' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='head -20 filetoview Display the first 20 lines of' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='lines of the file' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='called filetoview' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='tail filetoview Display the last 10 lines of the' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='of the file' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='called filetoview' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='tail -20 filetoview Display the last 20 lines of' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='lines of the file' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='called filetoview\nInstalling software for Linux' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='rpm -ihv name.rpm Install the rpm package called' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='called name' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='rpm -Uhv name.rpm Upgrade the rpm package called' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='name\nrpm -e package Delete the rpm package called' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='package' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='rpm -l package List the files in the package' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='package called' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='package' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='rpm -ql package List the files and state the' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='state the installed' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='version of the package called\npackage' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='rpm -i --force package Reinstall the rpm package' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='package called' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='name having deleted parts of it (not' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='deleting using rpm -e)' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='tar -zxvf archive.tar.gz or' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='tar -zxvf archive.tgzDecompress the files' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='the files contained in' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='the zipped and tarred archive called\narchive' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='./configure Execute the script preparing the' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='installed files for compiling\nUser Administration' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='adduser accountname Create a new user call' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='user call accountname' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='passwd accountname Give accountname a new' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='a new password' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='su Log in as superuser from current login' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='exit Stop being superuser and revert to' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='normal user\nLittle known tips and tricks' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='ifconfig List ip addresses for all devices on' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='the machine' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='apropos subject List manual pages for subject' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='usermount Executes graphical application for' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='mounting and unmounting file\nsystems' metadata={'source': 'testing.pdf', 'page': 0}
# page_content='/sbin/e2fsck hda5 Execute the filesystem check' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='check utility' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='on partition hda5' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='fdformat /dev/fd0H1440 Format the floppy disk in' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='disk in device fd0' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='tar -cMf /dev/fd0 Backup the contents of the' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='of the current' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='directory and subdirectories to' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='multiple floppy disks' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='tail -f /var/log/messages Display the last 10' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='last 10 lines of the system' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='log.' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='cat /var/log/dmesg Display the file containing' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='the boot' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='time messages - useful for locating' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='problems. Alternatively, use the\ndmesg  command.' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='* wildcard - represents everything. eg.' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='cp from/* to  will copy all files in the' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='from directory to the to directory' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='? Single character wildcard. eg.' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='cp config.? /configs will copy all files' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='beginning with the name config. in' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='the current directory to the directory' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='named configs.' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='[xyz] Choice of character wildcards. eg.' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='ls [xyz]* will list all files in the current' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='directory starting with the letter x, y,\nor z.' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='linux single At the lilo prompt, start in single' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='in single user' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='mode. This is useful if you have' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='forgotten your password. Boot in' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='single user mode, then run the\npasswd  command.' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='ps List current processes' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='kill 123 Kill a specific process eg. kill 123' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='Configuration files and what they do' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='/etc/profile System wide environment variables' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='variables for' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='all users.' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='/etc/fstab List of devices and their associated' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='mount' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='points. Edit this file to add cdroms, DOS' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='partitions and floppy drives at startup.' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='/etc/motd Message of the day broadcast to all' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='to all users' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='at login.' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='etc/rc.d/rc.local Bash script that is executed at' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='at the end of' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='login process. Similar to autoexec.bat in\nDOS.' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='/etc/HOSTNAME Conatins full hostname including' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='including domain.' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='/etc/cron.* There are 4 directories that' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='that automatically' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='execute all scripts within the directory at' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='intervals of hour, day, week or month.' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='/etc/hosts A list of all know host names and IP' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='addresses on the machine.' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='/etc/httpd/conf Paramters for the Apache web' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='web server' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='/etc/inittab Specifies the run level that the' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='that the machine' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='should boot into.' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='/etc/resolv.conf Defines IP addresses of DNS' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='of DNS servers.' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='/etc/smb.conf Config file for the SAMBA server.' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='server. Allows' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='file and print sharing with Microsoft\nclients.' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='clients.\n/etc/X11/XF86Confi' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='gConfig file for X -Windows.' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='~/.xinitrc Defines the windows manager loaded by' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='X. ~ refers to user’s home directory.File' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='permissions' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='If the command ls -l is given, a long list of' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='list of file names is' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='displayed. The first column in this list details' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='details the permissions' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='applying to the file. If a permission is missing' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='missing for a owner,' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='group of other, it is represented by - eg.  drwxr' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='drwxr -x—x' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='Read = 4\nWrite = 2' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='Execute = 1File permissions are altered by giving' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='by giving the' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='chmod command and the appropriate' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='octal code for each user type. eg' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='chmod 7 6 4 filename will make the file' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='called filename R+W+X for the owner,' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='R+W for the group and R for others.' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='chmod 7 5 5 Full permission for the owner, read' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='read and' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='execute access for the group and others.' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='chmod +x filename Make the file called filename' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='filename executable' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='to all users.\nX Shortcuts - (mainly for Redhat)' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='Control|Alt  + or - Increase or decrease the' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='the screen' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='resolution. eg. from 640x480 to\n800x600' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='Alt | escape Display list of active windows' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='Shift|Control F8 Resize the selected window' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='Right click on desktop\nbackgroundDisplay menu' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='Shift|Control Altr Refresh the screen' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='Shift|Control Altx Start an xterm session' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='Printing' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='/etc/rc.d/init.d/lpd start Start the print daemon' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='/etc/rc.d/init.d/lpd stop Stop the print daemon' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='/etc/rc.d/init.d/lpd' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='statusDisplay status of the print daemon' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='lpq Display jobs in print queue' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='lprm Remove jobs from queue\nlpr Print a file' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='lpc Printer control tool' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='man subject | lpr Print the manual page called' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='called subject' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='as plain text' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='man -t subject | lpr Print the manual page called' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='called subject' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='as Postscript output' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='printtool Start X printer setup' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='setup interface~/.Xdefaults Define configuration' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='for some X -' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='applications. ~ refers to user’s home\ndirectory.' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='Get your own Official Linux Pocket Protector -' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='- includes' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='handy command summary. Visit:' metadata={'source': 'testing.pdf', 'page': 1}
# page_content='www.powerup.com.au/~squadron' metadata={'source': 'testing.pdf', 'page': 1}
